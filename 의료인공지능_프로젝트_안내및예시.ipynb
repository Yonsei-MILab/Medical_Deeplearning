# %% [markdown]
# # 의료머신러닝 프로젝트 안내
#
# 의료머신러닝 프로젝트 제출해야할 주피터 노트북 예시파일 입니다. 아래의 코드는 이해를 위해 임의로 나뉘어진 섹션입니다.
#
# - 프로젝트 안내 사항
# 1. Dataset은 와이섹에서 다운받으실 수 있습니다.
# 2. 코드를 다 돌린 후 각 섹션의 결과가 출력된 상태로 저장하셔서 보내주시기 바랍니다.
# 3. 공개된 Dataset에 포함되어 있지 않은 test set 2 로 추가적인 ROC curve 확인이 있습니다. 네트워크가 overfitting 되지 않도록 유의해주시기 바랍니다.
#
# - 코드 작성 및 제출 시 유의사항
# 1. Pytorch, tensorflow, keras 중 하나를 이용해 코딩하시면 됩니다.
# 2. 코드를 돌릴 때 에러가 발생할 경우 감점이 있습니다.
# 3. test set 은 와이섹에 올려드린 Dataset 중 뒤에서부터 600개를 사용하시기 바랍니다.
# 4. weight 를 load 하는 코드가 없는 경우 감점이 있습니다.
#
# - 최종 프로젝트 제출 안내
# 1. 프로젝트 파일 제출시 최종 제출하셔야할 파일은 **1. 주피터 노트북 파일 2. Weight 3. 보고서** 입니다. 세가지 중 하나라도 제출하지 않을 시 감점이 있으므로 유의하시기 바랍니다.
# 2. 제출 할 세가지 파일을 하나로 압축하셔서 '학번_이름.zip' 이름으로 업로드 해주시기 바랍니다. ex. '2019123456_홍길동.zip'

# %%
# Load libraries

# %% [markdown]
# <h2> 1. Data Preprocessing

# %%
# Dataset load

# %%
# Data preprocessing1 (ex. Image resize, data normalization etc.)

# %%
# Plot the preprocessed dataset

# %%
# Data preprocessing2 (ex. Change the dataset array, Change the data type (Numpy to tensor) etc.)

# %%
# Seperate the training/validation/testset
# 와이섹에 올려드린 Dataset은 총 4000개의 데이터 입니다. 그 중 뒤에서부터 600개의 데이터를 데스트 셋으로 사용해주시기 바랍니다. (그렇지 않을 시 감점이 있습니다)
# Training/Validation 은 임의로 설정된 비율이니 수정하셔도 됩니다.

# 예시코드
# train = data[:3000]
# val = data[3000:3400]
# test = data[3400:]

# %% [markdown]
# <h2> 2. Model Architecture

# %%
# 보고서에 있는 기존 아키텍쳐로 test 하는 문제에 대한 코드는 작성하지 않고 새로운 네트워크에 대한 코드만 작성해주시기 바랍니다.
# Design your own architecture

# %%
# Parameters setting
# Model define
# Optimization and loss define

# %% [markdown]
# <h2> 3. Train & Evaluation Functions

# %%
# Train your network

# %%
# save weight

# %%
# load weight

# %%
# Predict the testset

# %% [markdown]
# <h3> 3.1. Receiver Operating Characteristic curve

# %%
# Plot the ROC curve

# %% [markdown]
# <h3> 3.2. Confusion Matrix

# %%
# Plot the confusion matrix
